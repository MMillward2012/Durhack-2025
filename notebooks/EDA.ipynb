# %% [markdown]
# # Exploratory Data Analysis for Tweet Polarization
#
# This notebook explores the first 100 tweets on a given topic to analyze their sentiment and predict whether the topic will become polarized or die off.
